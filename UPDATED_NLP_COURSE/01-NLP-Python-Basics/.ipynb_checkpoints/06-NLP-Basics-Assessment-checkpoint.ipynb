# %% [markdown]
# ___
#
# <a href='http://www.pieriandata.com'> <img src='../Pierian_Data_Logo.png' /></a>
# ___

# %% [markdown]
# # NLP Basics Assessment

# %% [markdown]
# For this assessment we'll be using the short story [_An Occurrence at Owl Creek Bridge_](https://en.wikipedia.org/wiki/An_Occurrence_at_Owl_Creek_Bridge) by Ambrose Bierce (1890). <br>The story is in the public domain; the text file was obtained from [Project Gutenberg](https://www.gutenberg.org/ebooks/375.txt.utf-8).

# %%
# RUN THIS CELL to perform standard imports:
import spacy
nlp = spacy.load('en_core_web_sm')
# Out:
# C:\Users\Max\anaconda3\lib\site-packages\cupy\_environment.py:206: UserWarning: CUDA path could not be detected. Set CUDA_PATH environment variable if CuPy fails to load.
#   'CUDA path could not be detected.'
# C:\Users\Max\anaconda3\lib\site-packages\cupy\_environment.py:206: UserWarning: CUDA path could not be detected. Set CUDA_PATH environment variable if CuPy fails to load.
#   'CUDA path could not be detected.'
# C:\Users\Max\anaconda3\lib\site-packages\cupy\_environment.py:206: UserWarning: CUDA path could not be detected. Set CUDA_PATH environment variable if CuPy fails to load.
#   'CUDA path could not be detected.'
# C:\Users\Max\anaconda3\lib\site-packages\cupy\_environment.py:206: UserWarning: CUDA path could not be detected. Set CUDA_PATH environment variable if CuPy fails to load.
#   'CUDA path could not be detected.'

# %% [markdown]
# **1. Create a Doc object from the file `owlcreek.txt`**<br>
# > HINT: Use `with open('../TextFiles/owlcreek.txt') as f:`

# %%
# Enter your code here:

with open('../TextFiles/owlcreek.txt') as f:
    doc = nlp(f.read())

# %%
# Run this cell to verify it worked:

doc[:36]
# Out:
# AN OCCURRENCE AT OWL CREEK BRIDGE
#
# by Ambrose Bierce
#
# I
#
# A man stood upon a railroad bridge in northern Alabama, looking down
# into the swift water twenty feet below.

# %% [markdown]
# **2. How many tokens are contained in the file?**

# %%
print(len(doc))
tokens_list = []
for token in doc:
    tokens_list.append(token.text)
print(tokens_list)
# Out:
# 4835
# ...

# %% [markdown]
# **3. How many sentences are contained in the file?**<br>HINT: You'll want to build a list first!

# %%
sentences = [sent for sent in doc.sents]
print(len(sentences))
for sent in sentences:
    print(sent, "END", sent.end)
# Out:
# 204
# AN OCCURRENCE AT OWL CREEK BRIDGE
#
# by Ambrose Bierce
#
# I
#
# A man stood upon a railroad bridge in northern Alabama, looking down
# into the swift water twenty feet below.   END 36
# The man's hands were behind
# his back, the wrists bound with a cord.   END 54
# A rope closely encircled his
# neck.   END 63
# It was attached to a stout cross-timber above his head and the
# slack fell to the level of his knees.   END 88
# Some loose boards laid upon the
# ties supporting the rails of the railway supplied a footing for him
# and his executioners--two private soldiers of the Federal army,
# directed by a sergeant who in civil life may have been a deputy
# sheriff.   END 138
# At a short remove upon the same temporary platform was an
# officer in the uniform of his rank, armed.   END 161
# He was a captain.   END 167
# A
# sentinel at each end of the bridge stood with his rifle in the
# position known as "support," that is to say, vertical in front of the
# ...

# %% [markdown]
# **4. Print the second sentence in the document**<br> HINT: Indexing starts at zero, and the title counts as the first sentence.

# %%
print(sentences[0].text)
# Out:
# AN OCCURRENCE AT OWL CREEK BRIDGE
#
# by Ambrose Bierce
#
# I
#
# A man stood upon a railroad bridge in northern Alabama, looking down
# into the swift water twenty feet below.

# %% [markdown]
# ** 5. For each token in the sentence above, print its `text`, `POS` tag, `dep` tag and `lemma`<br>
# CHALLENGE: Have values line up in columns in the print output.**

# %%
# NORMAL SOLUTION:
for token in sentences[0]:
    print(token.text, token.pos_, token.dep_, token.lemma_)
# Out:
# AN DET det an
# OCCURRENCE NOUN nmod occurrence
# AT PROPN prep AT
# OWL PROPN compound OWL
# CREEK PROPN compound CREEK
# BRIDGE PROPN ROOT BRIDGE
#
#
#  SPACE dep
#
#
# by ADP prep by
# Ambrose PROPN compound Ambrose
# Bierce PROPN pobj Bierce
#
#
#  SPACE dep
#
#
# I PRON punct I
#
#
#  SPACE dep
#
#
# A DET det a
# man NOUN nsubj man
# stood VERB relcl stand
# upon SCONJ prep upon
# a DET det a
# railroad NOUN compound railroad
# bridge NOUN pobj bridge
# in ADP prep in
# northern ADJ amod northern
# Alabama PROPN pobj Alabama
# , PUNCT punct ,
# looking VERB advcl look
# down ADV advmod down
#
#  SPACE dep
#
# into ADP prep into
# the DET det the
# swift ADJ amod swift
# water NOUN pobj water
# twenty NUM nummod twenty
# feet NOUN npadvmod foot
# below ADV advmod below
# . PUNCT punct .
#   SPACE dep

# %%
# CHALLENGE SOLUTION:
for token in sentences[0]:
    print(f'{token.text:{15}} {token.pos_:{5}} {token.dep_:{10}} {token.lemma_:{15}} {token.tag_:{3}} {token.is_stop}')
# Out:
# AN              DET   det        an              DT  True
# OCCURRENCE      NOUN  nmod       occurrence      NN  False
# AT              PROPN prep       AT              NNP True
# OWL             PROPN compound   OWL             NNP False
# CREEK           PROPN compound   CREEK           NNP False
# BRIDGE          PROPN ROOT       BRIDGE          NNP False
#
#
#               SPACE dep
#
#               _SP False
# by              ADP   prep       by              IN  True
# Ambrose         PROPN compound   Ambrose         NNP False
# Bierce          PROPN pobj       Bierce          NNP False
#
#
#               SPACE dep
#
#               _SP False
# I               PRON  punct      I               PRP True
#
#
#               SPACE dep
#
#               _SP False
# A               DET   det        a               DT  True
# man             NOUN  nsubj      man             NN  False
# stood           VERB  relcl      stand           VBD False
# ...

# %% [markdown]
# **6. Write a matcher called 'Swimming' that finds both occurrences of the phrase "swimming vigorously" in the text**<br>
# HINT: You should include an `'IS_SPACE': True` pattern between the two words!

# %%
# Import the Matcher library:

from spacy.matcher import Matcher
matcher = Matcher(nlp.vocab)

# %%
# Create a pattern and add it to matcher:

pattern = [{'LOWER': 'swimming'}, {'IS_SPACE': True, 'OP':'*'}, {'LOWER': 'vigorously'}]
pattern2 = [{'LOWER': 'discover'}]
matcher.add('Swimming', [pattern])
matcher.add('Discover', [pattern2])

# %%
# Create a list of matches called "found_matches" and print the list:

found_matches = matcher(doc)
print(found_matches)
# Out:
# [(12881893835109366681, 1274, 1277), (12881893835109366681, 3609, 3612), (15197724036484644630, 4254, 4255)]

# %% [markdown]
# **7. Print the text surrounding each found match**

# %%
print(doc[1265:1290])
# Out:
# By diving I could evade the bullets and, swimming
# vigorously, reach the bank, take to the woods and get away home

# %%
print(doc[3600:3620])
# Out:
# all this over his shoulder; he was now swimming
# vigorously with the current.  His brain was

# %%
print(doc[4240:4270])
# Out:
# the rounding sun.  The
# forest seemed interminable; nowhere did he discover a break in it, not
# even a woodman's road.  He

# %% [markdown]
# **EXTRA CREDIT:<br>Print the *sentence* that contains each found match**

# %%
for sent in sentences:
    if found_matches[0][1] < sent.end:
        print(found_matches[0][1])
        print(sent.end)
        print(sent)
        break
# Out:
# 1274
# 1292
# By diving I could evade the bullets and, swimming
# vigorously, reach the bank, take to the woods and get away home.

# %%
for sent in sentences:
    if found_matches[1][1] < sent.end:
        print(found_matches[1][1])
        print(sent.end)
        print(sent)
        break
# Out:
# 3609
# 3617
# The hunted man saw all this over his shoulder; he was now swimming
# vigorously with the current.

# %%
for sent in sentences:
    if found_matches[2][1] < sent.end:
        print(found_matches[2][1])
        print(sent.end)
        sent_text = sent.text.replace('\n', ' ')
        print(sent_text)
        break
# Out:
# 4254
# 4269
# The forest seemed interminable; nowhere did he discover a break in it, not even a woodman's road.

# %% [markdown]
# ### Great Job!
